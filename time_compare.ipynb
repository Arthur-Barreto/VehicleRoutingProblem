# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import time

# %% [markdown]
# ## Run global search for each file on `/input_files` and plot the time taken to each one

# %%
input_file_folder = os.path.join(os.getcwd(), 'input_files')

# %%
global_results = {}

for file in os.listdir(input_file_folder):
    # file format: grafoINT.txt
    # take the number from the file name
    graph_number = int(file[5:-4])
    start = time.time()
    # call the exe global_search with the input file
    os.system(f'./global_search {os.path.join(input_file_folder, file)} 15')
    end = time.time()
    global_results[graph_number] = end - start
# Out:
# Number of edges: 37
# Number of nodes: 12
# Best Route: 0 1 5 0 2 6 0 3 8 0 4 10 0 7 0 9 0 11 0
# Cost of the best route: 861
# Number of edges: 11
# Number of nodes: 5
# Best Route: 0 1 0 2 3 4 0
# Cost of the best route: 367
# Number of edges: 20
# Number of nodes: 8
# Best Route: 0 1 6 0 2 0 3 5 0 4 0 7 0
# Cost of the best route: 662
# Number of edges: 31
# Number of nodes: 10
# Best Route: 0 1 0 2 3 0 4 5 6 8 0 9 0 7 0
# Cost of the best route: 519
# Number of edges: 27
# Number of nodes: 11
# Best Route: 0 1 7 0 2 5 0 3 0 4 0 6 0 8 0 9 0 10 0
# Cost of the best route: 924
# Number of edges: 16
# Number of nodes: 7
# Best Route: 0 1 6 0 2 4 0 3 0 5 0
# Cost of the best route: 563
# Number of edges: 23
# Number of nodes: 9
# Best Route: 0 1 0 2 3 0 4 6 0 5 0 7 0 8 0
# Cost of the best route: 496
# Number of edges: 12
# Number of nodes: 6
# Best Route: 0 1 2 0 3 0 4 0 5 0
# Cost of the best route: 373
# Number of edges: 7
# Number of nodes: 4
# Best Route: 0 1 0 2 3 0
# Cost of the best route: 286

# %%
plt.plot(list(global_results.keys()), list(global_results.values()), 'ro')
plt.xlabel('Graph number')
plt.ylabel('Execution time')
plt.title('Global search execution time')
plt.show()

# %% [markdown]
# ## Run Heuristic search for each file on `/input_files` and plot the time taken to each one

# %%
heuristic_results = {}

for file in os.listdir(input_file_folder):
    # file format: grafoINT.txt
    # take the number from the file name
    graph_number = int(file[5:-4])
    start = time.time()
    # call the exe heuristic_search with the input file
    os.system(f'./heuristic_search {os.path.join(input_file_folder, file)} 15')
    end = time.time()
    heuristic_results[graph_number] = end - start
# Out:
# Number of edges: 37
# Number of nodes: 12
# Best Route: 0 1 5 0 9 0 3 8 0 2 6 0 7 0 4 10 0 11 0
# Cost of the best route: 861
# Number of edges: 11
# Number of nodes: 5
# Best Route: 0 1 0 2 3 4 0
# Cost of the best route: 367
# Number of edges: 20
# Number of nodes: 8
# Best Route: 0 3 5 0 4 0 1 6 0 2 0 7 0
# Cost of the best route: 662
# Number of edges: 31
# Number of nodes: 10
# Best Route: 0 2 3 0 9 0 1 0 7 0 4 5 6 8 0
# Cost of the best route: 519
# Number of edges: 27
# Number of nodes: 11
# Best Route: 0 6 0 8 0 10 0 9 0 1 7 0 3 0 2 5 0 4 0
# Cost of the best route: 924
# Number of edges: 16
# Number of nodes: 7
# Best Route: 0 2 4 0 5 0 1 6 0 3 0
# Cost of the best route: 563
# Number of edges: 23
# Number of nodes: 9
# Best Route: 0 4 6 0 1 0 7 0 5 0 2 3 0 8 0
# Cost of the best route: 496
# Number of edges: 12
# Number of nodes: 6
# Best Route: 0 1 2 0 3 0 5 0 4 0
# Cost of the best route: 373
# Number of edges: 7
# Number of nodes: 4
# Best Route:
# Segmentation fault (core dumped)

# %%
plt.plot(list(heuristic_results.keys()), list(heuristic_results.values()), 'ro')
plt.xlabel('Number of nodes')
plt.ylabel('Execution time')
plt.title('Heuristic search execution time')
plt.show()

# %% [markdown]
# ## Run parallel_seach for each file on `/input_files` and plot the time taken to each one

# %%
parallel_search = {}

for file in os.listdir(input_file_folder):
    # file format: grafoINT.txt
    # take the number from the file name
    graph_number = int(file[5:-4])
    start = time.time()
    # call the exe parallel_search with the input file
    os.system(f'./parallel_search {os.path.join(input_file_folder, file)} 15')
    end = time.time()
    parallel_search[graph_number] = end - start
# Out:
# Number of edges: 37
# Number of nodes: 12
# Best Route: 0 7 0 11 0 4 10 0 9 0 1 5 0 2 6 0 3 8 0
# Cost of the best route: 861
# Number of edges: 11
# Number of nodes: 5
# Best Route: 0 1 0 2 3 4 0
# Cost of the best route: 367
# Number of edges: 20
# Number of nodes: 8
# Best Route: 0 1 6 0 2 0 4 0 3 5 0 7 0
# Cost of the best route: 662
# Number of edges: 31
# Number of nodes: 10
# Best Route: 0 1 0 2 3 0 4 5 6 8 0 9 0 7 0
# Cost of the best route: 519
# Number of edges: 27
# Number of nodes: 11
# Best Route: 0 10 0 4 0 3 0 8 0 6 0 2 5 0 9 0 1 7 0
# Cost of the best route: 924
# Number of edges: 16
# Number of nodes: 7
# Best Route: 0 2 4 0 5 0 1 6 0 3 0
# Cost of the best route: 563
# Number of edges: 23
# Number of nodes: 9
# Best Route: 0 4 6 0 7 0 8 0 1 0 2 3 0 5 0
# Cost of the best route: 496
# Number of edges: 12
# Number of nodes: 6
# Best Route: 0 1 2 0 3 0 4 0 5 0
# Cost of the best route: 373
# Number of edges: 7
# Number of nodes: 4
# Best Route: 0 1 0 2 3 0
# Cost of the best route: 286

# %%
plt.plot(list(parallel_search.keys()), list(parallel_search.values()), 'ro')
plt.xlabel('Number of Nodes')
plt.ylabel('Execution time (s)')
plt.title('Parallel search execution time')
plt.show()

# %% [markdown]
# ## Compare the time taken for all the methods

# %%
plt.plot(list(global_results.keys()), list(global_results.values()), 'rx', label='Global search')
plt.plot(list(parallel_search.keys()), list(parallel_search.values()), 'bx', label='Parallel search')
plt.plot(list(heuristic_results.keys()), list(heuristic_results.values()), 'gx', label='Heuristic search')
plt.xlabel('Number of Nodes')
plt.ylabel('Execution time (s)')
plt.title('Execution time comparison')
plt.legend()
